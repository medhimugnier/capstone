# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

plt.style.use('fivethirtyeight')

from ipywidgets import *
from IPython.display import display

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv("/Users/medhimugnier/Desktop/capstone/datasets/2015-2016_passagesRM_LesGets - Tabelle1.csv")

# %%
df.head()
# Out:
#   Passages-résumé rapport détaillé             Unnamed: 1 Unnamed: 2  \
# 0        Regroupement par remontée                    NaN        NaN
# 1                        Société :  S.A.G.E.T.S [PDS New]        NaN
# 2                 Nom du rapport :               Passages        NaN
# 3                              NaN                    NaN        NaN
# 4                              NaN                    NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6                   Unnamed: 7  \
# 0        NaN        NaN        NaN         NaN                          NaN
# 1        NaN        NaN    Période  19.10.2015                            -
# 2        NaN        NaN        NaN         NaN  ERROR AUTO SAGETS global re
# 3        NaN        NaN  Remontées         NaN                          NaN
# 4        NaN        NaN        NaN         NaN                          NaN
#
#    Unnamed: 8
# 0         NaN
# 1  30.04.2016
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.shape
# Out:
# (6641, 9)

# %%
df = df[df['Passages-résumé rapport détaillé'] != 'Regroupement par remontée']
df = df[df['Passages-résumé rapport détaillé'] != 'Société :']
df = df[df['Passages-résumé rapport détaillé'] != 'Nom du rapport :']
df = df[df['Passages-résumé rapport détaillé'] != 'Installation']
df = df[df['Passages-résumé rapport détaillé'] != 'Passages-résumé rapport détaillé']
df = df[df['Unnamed: 5'] != 'Remontées']
df = df[df['Unnamed: 2'] != 'Rapport Axess AG V8.0.08  114/2  (DB V11.1.00.00)']
df = df[df['Unnamed: 2'] != 'Rapport Axess AG V8.0.08  114/2  (DB V11.1.00.00)']
df = df[df['Unnamed: 1'] != '13.12.2016 14:42']
df = df[df.date != 'Somme']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-e3178b9c2d57> in <module>()
# ----> 1 df = df[df['Passages-résumé rapport détaillé'] != 'Regroupement par remontée']
#       2 df = df[df['Passages-résumé rapport détaillé'] != 'Société :']
#       3 df = df[df['Passages-résumé rapport détaillé'] != 'Nom du rapport :']
#       4 df = df[df['Passages-résumé rapport détaillé'] != 'Installation']
#       5 df = df[df['Passages-résumé rapport détaillé'] != 'Passages-résumé rapport détaillé']
#
# /Users/medhimugnier/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# ...

# %%
df = df.dropna(how='all')

# %%
df = df[df.date != 'Total']

# %%
df.head()
# Out:
#           date             libre_permanent libre_manuel passages_forces  \
# 6          NaN  160 TK Super Chery     160          NaN             NaN
# 8   19.10.2015                           0            0               0
# 9   20.10.2015                           0            0               0
# 10  21.10.2015                           0            0               0
# 11  22.10.2015                           0            0               0
#
#    forfaits transaction difference    - total
# 6       NaN         NaN        NaN  NaN   NaN
# 8         0           0          0  NaN     0
# 9         0           0          0  NaN     0
# 10        0           0          0  NaN     0
# 11        0           0          0  NaN     0

# %%
def fill_the_gaps(lift):
    lifts = ['None']
    
    if len(lift) > 5:
        lifts.append(lift)
        pass
    
    else:
        lift = lifts[-1]
        return lift

# %%
lifts = ['None']

def fill_the_gaps(lift):
    
    if len(lift) > 5:
        lifts.append(lift)
        return lift
    
    else:
        lift = lifts[-1]
        return lift

# %%
df.insert(0,'lift_fill_in3',df['libre_permanent'].map(lambda x : fill_the_gaps(x)))

# %%
df = df.drop(['lift_fill_in2','lift_fill_in'],1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-b46886d1af04> in <module>()
# ----> 1 df = df.drop(['lift_fill_in2','lift_fill_in'],1)
#       2 df
#
# /Users/medhimugnier/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/medhimugnier/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
#df = df[:-1]

# %%
len(df.lift.values[0])
# Out:
# True

# %%
df = df[df['libre_permanent'].str.len() < 5]

# %%
df.drop('lift',1, inplace = True)
# Out:
# /Users/medhimugnier/anaconda/envs/dsi/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.rename(columns = {'lift_fill_in3':'lift'}, inplace = True)
# Out:
# /Users/medhimugnier/anaconda/envs/dsi/lib/python2.7/site-packages/pandas/core/frame.py:2754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
df.to_csv('lesgetsdatacleaned.csv')

# %%
df
# Out:
#                             lift        date libre_permanent libre_manuel  \
# 8     160 TK Super Chery     160  19.10.2015               0            0
# 9     160 TK Super Chery     160  20.10.2015               0            0
# 10    160 TK Super Chery     160  21.10.2015               0            0
# 11    160 TK Super Chery     160  22.10.2015               0            0
# 12    160 TK Super Chery     160  23.10.2015               0            0
# 13    160 TK Super Chery     160  24.10.2015               0            0
# 14    160 TK Super Chery     160  25.10.2015               0            0
# 15    160 TK Super Chery     160  26.10.2015               0            0
# 16    160 TK Super Chery     160  27.10.2015               0            0
# 17    160 TK Super Chery     160  28.10.2015               0            0
# 18    160 TK Super Chery     160  29.10.2015               0            0
# 19    160 TK Super Chery     160  30.10.2015               0            0
# ...
